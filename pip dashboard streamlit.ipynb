# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import plotly.express as px
import pickle

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Memanggil dataframe

# %%
df = pd.read_csv("netflix_titles.csv")
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df["release_year"].value_counts()
# Out:
# 2018    1147
# 2017    1032
# 2019    1030
# 2020     953
# 2016     902
#         ...
# 1959       1
# 1925       1
# 1961       1
# 1947       1
# 1966       1
# Name: release_year, Length: 74, dtype: int64

# %% [markdown]
# Menampilkan kolom

# %%
df.columns

# %% [markdown]
# Membuat data untuk memilih kolom yang dibutuhkan

# %%
data = df[["type", "release_year", "title"]]

# %%
data.isnull().sum()
# Out:
# type            0
# release_year    0
# title           0
# dtype: int64

# %%
data.to_pickle("data_input.pickle")

# %%
type

# %%
type = ["All Type"] + list(data["type"].value_counts().keys().sort_values())

# %%
type

# %%
data
# Out:
#          type  release_year                  title
# 0       Movie          2020   Dick Johnson Is Dead
# 1     TV Show          2021          Blood & Water
# 2     TV Show          2021              Ganglands
# 3     TV Show          2021  Jailbirds New Orleans
# 4     TV Show          2021           Kota Factory
# ...       ...           ...                    ...
# 8802    Movie          2007                 Zodiac
# 8803  TV Show          2018            Zombie Dumb
# 8804    Movie          2009             Zombieland
# 8805    Movie          2006                   Zoom
# 8806    Movie          2015                 Zubaan
#
# [8807 rows x 3 columns]

# %%
def recommend(type, release_year):
    recommendations = data[(data['type'] == type) & (data['release_year'] == release_year)]
    return recommendations['title'].tolist()

# Example usage
print(recommend('Movie', 2020))  # Recommends 'Dick Johnson Is Dead'
print(recommend('TV Show', 2021))
# Out:
# ['Dick Johnson Is Dead', "Europe's Most Dangerous Man: Otto Skorzeny in Spain", 'Tughlaq Durbar', 'Omo Ghetto: the Saga', 'Shadow Parties', 'Here and There', 'Shikara', 'Really Love', 'The Old Ways', 'A Faraway Land', 'Nneka The Pretty Serpent', 'Out of my league', 'Unroyal', 'La diosa del asfalto', 'Takizawa Kabuki ZERO 2020 The Movie', "Quam's Money", "I'm Glad I Did", 'Sanitation Day', 'Milkwater', '2 Weeks in Lagos', 'Born to Play', 'Finding Hubby', 'Clash', 'Mama Drama', 'Therapy', 'Har Kisse Ke Hisse: Kaamyaab', 'Holiday on Mars', 'RattleSnake - The Ahanna Story', 'Voiceless', 'Deranged', 'A Way Back Home', 'Kambili: The Whole 30 Yards', 'Fan Girl', 'Silver Skates', 'Rogue Warfare: Death of a Nation', 'Picture a Scientist', 'Small Chops', 'From Stress to Happiness', '2 Hearts', 'Sam Smith: Love Goes - Live at Abbey Road Studios', 'Strain', 'Hating Peter Tatchell', 'Love or Money', 'The Strange House', 'Wave of Cinema: Filosofi Kopi', 'Dear Affy', 'Illegal Woman', "In Our Mother
# ...

# %%
import pickle

# Define function to recommend titles based on type and release year
def recommend(type, release_year):
    # ... implementation of the function ...

# Save the function to a file using pickle
    with open('recommend.pkl', 'wb') as f:
        pickle.dump(recommend, f)
